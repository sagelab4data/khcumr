# %% [markdown]
# 마케팅조사론 수강생 여러분, 코랩 Colab에 오신 것을 환영합니다. 코랩 Colab의 중요한 기능을 살펴봅니다
#
# <p><img alt="Colaboratory logo" height="45px" src="/img/colab_favicon.ico" align="left" hspace="10px" vspace="0px"></p>
# <h1>Colaboratory란?</h1>
#
# 줄여서 '코랩 Colab'이라고도 하는 코래버레이토리 Colaboratory를 사용하면 브라우저에서 파이썬 Python을 작성하고 실행할 수 있습니다.
#
# 코랩의 장점으로는
# - 설치가 필요하지 않다.
# - 계산 능력이 뛰어난 GPU를 사용할 수 있다.
# - 작업자간에 공유가 쉽다
#
# <strong>학생</strong>, <strong>데이터 과학자</strong> , <strong>AI 인공지능 연구원</strong> 모두가 간편하게 분석 할 수 있습니다.

# %% [markdown]
# ## **1.코랩 노트 만들기 읽어오기 저장하기**
#
# ***코랩 노트***를 사용하면 <strong>실행 코드</strong>와 <strong>텍스트</strong>를 <strong>이미지</strong> 등과 함께 저장 할 수 있습니다.
#
#
# * **코랩 노트 만들기** : 위의 **파일 -  새 노트** 메뉴를 사용하세요. ***코랩 노트***를 만들면 구글 드라이브 (G Drive)에 저장됩니다.
#
# * **코랩 노트 읽어오기** : 코드 공유사이트인 **깃허브 GitHub**로 부터 ***코랩 노트***을 읽어 들일 수 있습니다. (**'파일 - 노트 열기'**에서 GitHub 탭 선택)
#
# * **코랩 노트 저장하기**: 읽어 들인 파일은 **'파일-드라이브에 사본저장'** 을 통해 나의 구글 드라이브(G Drive)에 저장합니다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## <strong>2.시작하기</strong>
#
# 지금 읽고 있는 문서는 코드를 작성하고 실행할 수 있는 <strong>*코랩 노트북(메모장)*</strong>입니다.
#
# 값을 계산하여 변수로 저장하고 결과를 출력하는 간단한 파이썬 스크립트가 포함된 <strong>코드 셀</strong>을 살펴 봅시다.

# %% [markdown]
# **하루는 몇 초일까요?**

# %%
# sec_per_day 가 변수
sec_per_day = 24 * 60 * 60
sec_per_day

# %% [markdown]
# 위의 코드를 실행하려면 셀을 클릭하여 선택한 후,  코드 왼쪽의 실행 버튼을 누르거나, 단축키 'Ctrl+Enter'를 사용합니다. 셀을 클릭하면 바로 코드를  수정 할 수 있습니다.
#
# 어떤 셀에서 변수를 정의하면, 나중에 다른 셀에서 사용할 수 있습니다.

# %% [markdown]
# ## **3.데이터 과학**
#
# 코랩을 통해 파이썬의 풍부한 데이터 분석 라이브러리를 활용하여 데이터를 분석하고 시각화할 수 있습니다.
#
# * 아래 코드 셀에서는 <strong>넘파이Numpy</strong>를 사용하여 임의의 데이터를 생성하고 <strong>매트플롯립matplotlib</strong>으로 이를 시각화합니다.
#
# 엑셀 또는 CSV 등의 데이터를 구글 드라이브 G Drive 또는 깃허브 GitHub계정에서 코랩 노트북으로 가져올 수 있고, 직접 데이터를 만들어서 사용 할 수  있습니다.
#
# * 아래 예제에서는 직접 난수를 발생 시키고 이를 그래프로 표현해 봅니다. 셀을 클릭하고 실행해 봅시다.

# %%
# 숫자 연산을 다루는 numpy와 그래프를 그리는 matplotlib을 읽어 들입니다.
import numpy as np
import matplotlib.pyplot as plt

# numpy를 이용하여 난수 random value를 발생 시킵니다. 
ys = 200 + np.random.randn(100)
x = np.arange(0,100,1)

# matplotlib을 이용하여 그래프를 그립니다.
plt.plot(x, ys, '-')

# 그래프에 제목을 만들고 출력합니다. 
plt.title("Sample Visualization of Random Values")
plt.show()

# %% [markdown]
# ## **4.머신러닝**
#
# Colab을 사용하면 <a href="https://colab.research.google.com/github/tensorflow/docs/blob/master/site/en/tutorials/quickstart/beginner.ipynb">코드 몇 줄</a>만으로 머신러닝을 수행 할 수 있습니다. Colab 메모장은 Google 클라우드 서버에서 코드를 실행하므로 사용 중인 여러분의 컴퓨터 성능과 관계없이 <a href="#using-accelerated-hardware">GPU 및 TPU</a> 등  Google 서버를 활용할 수 있습니다. 여러분은 브라우저만 있으면 됩니다.
#
# ### 머신러닝 예시
#
# - <a href="https://tensorflow.org/hub/tutorials/tf2_arbitrary_image_stylization">스타일 트랜스퍼</a>: 딥 러닝을 사용하여 이미지 간에 스타일을 전이시킵니다.

# %% [markdown]
# ## **5.더 궁금하다면...**
# 아래 링크를 참조하세요
#
# ### Colab 공식 환영 메모장
# - [Colaboratory에 오신 것을 환영합니다](/notebooks/intro.ipynb)
#
# ### Colab에서 메모장 사용하기
# - [Colaboratory 개요](/notebooks/basic_features_overview.ipynb)
# - [Markdown 가이드](/notebooks/markdown_guide.ipynb)
