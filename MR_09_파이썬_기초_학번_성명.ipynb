# %% [markdown]
# # **파이썬 기초**

# %% [markdown]
# ## **0.코랩 소개 및 루틴 익히기**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **1.파이썬 기본 구문 1 : 변수, 자료형, 연산자**

# %% [markdown]
# ### **1.1 변수**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 1.1.1
# 파이썬은 변수 variable에 값을 저장하고 변수를 이용해서 코딩을 수행할 수 있다.

# 변수 x 에 30을 할당해보자. <- # 샵 표시 이후는 주석이라고 설명 글을 적을 수 있는 영역이 된다.
# 변수의 할당은 등호 = 에 의해 이루어진다.

x = ...

x   # 코드 셀 마지막 줄에 변수명을 적으면, 변수 값이 출력 된다.

# %%
# 1.1.2
# 변수 y에 51.5를 할당해 보자.

...

...

# %%
# 1.1.3
# x+y 를 z에 할당해보자.

...

...

# %%
# 1.1.4
# x와 y와 z을 print()  함수를 이용해서 출력해본다. (함수는 뒤에 다시 배운다. )
print( ... )
...  (y)
...

# %% [markdown]
# ### **1.2 자료형**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **[주요 자료형]**
#
# ---
# *   **int**  정수 : 0,1,2,3, -1,-2
# *   **float** 부동소수점 : 1.1,  0.1,  .1
# *   **str**  문자열 : '1.1', '0.1', "1.1"  (따옴표, 겹따옴표 모두 OK)
# *   **bool** 불리언  : True, False

# %%
# 1.2.1 자료형을 확인하는 함수로 type() 이 있다. x의 자료형을 살펴보자.  (hint : type (x) )
***

# %%
# 1.2.2   3,  3.2,   '3.2' , True 의 자료형을 살펴보자.
# 문자로 적힌 숫자 '리터럴' 의 자료형도 type 함수로 파악이 가능하다.
# 셀을 실행하고 출력값을 확인한다.

print (type ( 3 ))   # int
print (type (3.2))   # float
print (type ('3.2'))  # str
print (type (True))  # bool

# %% [markdown]
# ### **1.3 연산자**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 1.3.1  10 더하기 20을 출력해보자.

...

# %%
# 1.3.2  10 더하기 20 과 10.더하기 20.5를 수행해보자.
print( ...  )    # 10 + 20  정수끼리의 덧셈은 정수
print( ...  )    # 10. + 20.5 부동 소수점끼리의 덧셈은 부동소수점

# %%
# 1.3.3   다음의 사칙 연산을 수행해보자.곱셈은 * 나눗셈은 / 을 사용한다.
print (12 ...  5)  # 12 더하기 5
print (12 ... 5)   # 12 빼기 5
print (12 * 5)     # 12 곱하기 5
print (12 / 5)     # 12 나누기 5

# %%
# 1.3.4  나눗셈에 대해서 몫과 나머지를 따로 구해보자. //과 %를 사용한다.
print (12 ... 5)   # 12를 5로 나눈 몫
print (12 ... 5)   # 12를 5로 나눈 나머지
print (12 // 2.5)  # 12를 2.5로 나눈 몫

# %%
# 1.3.5 2의 2제곱, 2의 3제곱,  2의 제곱근(0.5 제곱) 을 나타내보자.  거듭제곱은 **로 표현한다.
# print 함수 호출 할 때, 문자열, 리터럴,  변수 등을 쉼표로 연결해서 전달 할 수 있다.

print ('2의 제곱은', ... )       # 2의 2제곱
print ('2의 3제곱은', ... )      # 2의 3제곱
print ('2의 제곱근은', ...  )  # 2의 제곱근 (0.5 제곱)

# %% [markdown]
# ### **1.4 연습문제**

# %% [markdown]
# 다음은 피타고라스의 정리이다.
#
#
# ![image.png](data:image/png;base64,...)
#
#
# a가 6이고 b가 8일 때, c의 길이를 구해본다.
#
#
# 1.   변수 a와 b에 각각 6과 8을 할당한다.
# 2.   c를  변수 a, b와 피타고라스 공식을 이용하여 연산식으로 구한다.
# 3.   '빗변 c의 길이 : 10 '  가 출력 되도록 문자열과 변수 c를 출력한다.

# %% [markdown]
# hint 빗변 C를 구하는 공식
# * $ c = \sqrt {a^2 +b^2}  $
# * 제곱 : $x^2$ ==> x**2
# * 제곱근 : $\sqrt x$ ==> x**0.5   ( 제곱근은 0.5승)
# * 연산 우선 순위를 지정하기 위해 괄호 () 를 사용

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 1.4.1 변수 a와 b에 각각 6과 8을 할당하고 그 값을 출력한다.

...

# %%
# 1.4.2 c를  변수 a, b를 이용한 연산식으로 구한다.
...

# %%
# 1.4.3 '빗변 c의 길이 : 10 ' 가 출력되도록 문자열과 변수 c를 출력한다.
...

# %% [markdown]
# ## **2.파이썬 기본 구문 2 : 자료구조**

# %% [markdown]
# ### **2.1 리스트**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * 대괄호 [ ] 를 사용하여 리스트를 표기
# * 각 항목은 요소element라 하고, 콤마로 구분
# * 요소를 선택하는 인덱싱과 잘라내는 슬라이싱이 가능
# * 요소 값으로 숫자, 문자열 등 어떠한 자료형의 데이터도 올 수 있으며, 하나의 리스트에 섞어서 구성할 수 있다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 2.1.1 교재에서 제시한 5개의 점수를 각각 score1 ~score5 까지의 변수에 저장한 다음,
#       합계 score_sum과 평균 score_avg 을 구해보자

score1 = 90
score2 = 85
score3 = 93
score4 = 77
score5 = ...

score_sum = ...
score_avg = ...

print ('합계:', ...,  '평균:', ...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 2.1.2  이번에는 자료구조 리스트를 이용해서 점수를 표현해 본다.  score 변수에 할당하고,
#        리스트를 이용해서 합계 score_sum_lst와 평균 score_avg_lst 를 구해보자.
#        리스트는 대괄호를 이용해서 정의한다.
#        리스트 요소의 합산에는 sum() 함수를 사용할 수 있다.

score = ...

score_sum_lst = ...
score_avg_lst = ... / 5

print ('합계:', score_sum_lst,  '평균:', score_avg_lst)

# %% [markdown]
# **[리스트의 인덱싱]**
#
#
#
# ---
# 리스트는 첫 번째 항목을 0으로 하는 오프셋을 대괄호안에 기술하여 해당 항목(요소)에 접근 할 수 있고, 이를 인덱싱이라고 한다.
# ![image.png](data:image/png;base64,...)

# %%
# 2.1.3   2 번째 학생의 점수를 score  리스트에서 출력해보자. (85를 출력)
...

# %%
# 2.1.4  앞에서 2번째 학생은 뒤에서 4번째 학생이다.
#        2 번째 학생의 점수를 score에서 음의 인덱스를 이용해서 출력해보자 (동일하게 85출력)
...

# %%
# 2.1.5  가장 마지막 학생의 점수를 score에서 출력해보자.
...

# %% [markdown]
# **[리스트의 슬라이싱]**
#
#
#
# ---
#
# 리스트에서 부분집합을 구하는 슬라이싱 문법이 있다.  다음과 같이 세미콜론 : 으로 구분 된다.
#
#
# *   start : stop : step  ( 시작 : 끝 : 간격 )
# *   stop에 해당하는 숫자는 포함되지 않는다.
# *    0 : 2 : 1     --> 첫 0번 오프셋 부터,  2 하나 앞 즉 1번 오프셋까지 1의 간격으로 부분집합을 구한다. '잘라낸다' (항목이 한 개더라도 리스트가 나온다)
#
# ![image.png](data:image/png;base64,...)

# %%
# 2.1.6  score에서 앞 2개의 데이터만을 포함하는 슬라이스를 구성해보자.
...

# %%
# 2.1.7 시작값이 0이거나 끝 값이 마지막 항목을 포함 할 경우,
#       숫자 start의 0, stop의 길이값 생략이 가능하다.
# 실행해 보세요!
score[:2]     # 2.1.6과 동일한 결과가 출력된다.

# %% [markdown]
# ### **2.2 연습문제**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 2.2.1  상기 그림의 list1, list2, list3 을 생성한다.

list1 = [...]
list2 = ['red','green','blue']
list3 = ['a','b','c','d']

# %%
# 2.2.2  list2의 마지막 항목을 출력하라. ('blue' 출력)
list2[...]

# %%
# 2.2.3 list3의 앞 2개 항목으로 구성된 부분리스트를 출력하라 (슬라이싱 사용, ['a','b'] 출력)
list3[ : ...]

# %% [markdown]
# ## **3.파이썬 기본 구문 3 : 함수**

# %% [markdown]
# * 프로그램에서의 함수는, 일련의 명령문을 묶어서 실행하여 같은 코딩을 반복하지 않도록 한다.
# * 수학의 함수처럼 인수를 전달 받아 , 결과를 반환할 수 있다.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **3.1 내장 함수 (Built In) 및 호출**

# %% [markdown]
# **[파이썬의 내장함수 Built-in Function]**
#
#
#
# ---
#
# 파이썬은 자주 사용될 기능에 대해서 기본으로 함수를 제공한다. (내장함수)
#
# 함수의 실행은 함수명 뒤에 괄호를 붙여서 호출한다.  필요한 경우, 괄호안에 인수를 전달한다.
#
#
# **주요 내장 함수**
# *   입출력 관련 : print() , input()
# *   자료형 확인 : type()
# *   집계 연산 : len(), sum(), max(), min()
# *   수치 연산 : abs(), round(),  pow()

# %%
# 3.1.1  위에서 작성한 score의 자료형을 확인해보자. (hint : type() )
score = [ 90, 85, 93, 77 , 88]

type(...)

# %%
# 3.1.2 score의 길이를 확인해보자.  (hint : len() )
...  # 같은 줄에 쉼표로 구분하여 출력한다.

# %%
# 3.1.3 score 리스트의 합산, 최대값, 최소값을 구해보자.   (hint : sum(), max(), min())
sum(...), ... , ...

# %%
# 3.1.4   -3.141592 의 절대값을 구해보자.  (hint : abs() )
...(-3.141592)

# %% [markdown]
# ### **3.2 사용자 정의 함수 정의**

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# 함수는 예약어 def로 정의를 시작한다.  함수명 뒤에 괄호를 열고, 호출시에 인수로 전달 받을 매개변수를 기술하고 콜론으로 불럭을 지정한다.
#
# 들여쓰기가 된 블럭안에서 실행할 명령어를 기술한다.
#
# return 예약어와 반환값을 통해 함수 결과를 정의한다.
#
# *   파이썬은 들여쓰기로 블럭을 정의한다.
# *   매개변수는 없는 경우 비워둔다.
# *   반환값이 없는 경우 return 줄은 없어도 된다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 3.2.1  어떤 숫자 num 를 입력하면  3 제곱을 반환하는 함수 cube를 정의해보자.
#        이어서 cube에 7을 인수로 전달 하여 호출해보자.

# 함수의 정의
...

# 함수의 호출  (들여쓰기 조심!)
cube(7)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 3.2.2 x에 10을 저장하고 cube함수를  x를 인수로 호출해보자.
...

# %% [markdown]
# ### **3.3 연습문제**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 3.3.1 그림 왼쪽의 2개 값을 더하는 함수 print_sum을 만들어보자.  그림 처럼 3,5를 인수로 호출하면 8을 반환한다.

# 함수의 정의
def print_sum( ...)) :
  return ...

# 함수의 호출
print_sum(3,5)

# %%
# 3.3.2 그림 오른쪽의 이름을 입력받아 인사를 출력하는 함수  print_name이 정의 되어 있다.
#       그림 처럼 '팽수' 또는 여러분의 이름을 인수로 함수를 호출해보자.


# 함수의 정의
def print_name(name):
  print( '안녕!', name )

# 함수의 호출
print_name(...)
print_name('정은')

# %% [markdown]
# ## **4.pandas 데이터프레임과 시리즈**

# %% [markdown]
# ### 4.1  데이터프레임 읽어들이기
# - 판다스 라이브러리 : import pandas as pd

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 4.1.1  pandas 라이브러리를 읽어들인다. (임포트)
...

# %% [markdown]
# - 봉사료 데이터 셋 : 씨본 라이브러리에서 데이터 셋으로 제공
# - 씨본 라이브러리 읽어들이기 : import seaborn as sns
# - 씨본 라이브러리에서 데이터셋 읽어들이기 : sns.load_dataset(데이터셋)

# %%
# 4.1.2 봉사료(tips) 정보를 seaborn 라이브러리에서 제공한다.
#  seaborn 라이브러리를 읽어들이고,  tips 데이터셋을 읽어들인다.

import seaborn as sns
tips = sns.load_dataset('tips')
tips

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 4.2 데이터프레임의 부분 출력
# - .head(), .tail()  : 데이터프레임 앞 5행,  뒷 5행
# - ['컬럼이름'] : 데이터프레임의 특정 컬럼 선택  --> 시리즈 생성
# - [['컬럼1','컬럼2',...]] : 데이터프레임의 특정 컬럼들 선택 --> 선택컬럼으로 데이터 프레임 생성

# %%
# 4.2.1 봉사료의 앞 5 레코드 출력
tips.head()

# %%
# 4.2.2 봉사료의 뒤 5 레코드 출력
tips....

# %%
# 4.2.3 'total_bill' 컬럼을 선택해서 추출해본다.  (시리즈 반환)

tips ...

# %%
# 4.2.4 'tip' 봉사료와 'sex'성별 컬럼을 추출해본다.
# 2개 이상의 컬럼 추출 (데이터프레임)
tips ...

# %% [markdown]
# ### 4.3 시리즈
# - 데이터프레임에서 하나의 컬럼을 선택하면 시리즈를 반환한다.
# - 시리즈도 .head(), .tail() 메소드로 부분을 선택할 수 있다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 4.3.1 봉사료 tips 데이터프레임에서 인원수'size' 컬럼을 선택해 본다.
# 시리즈가 반환된다.

tips ...

# %%
# 4.3.2 table_size 변수에  'size' 컬럼을 추출한 시리즈를 저장하고 출력한다.
#  따옴표가 있는 'size'은 변수인가? 컬럼명인가? --> 데이터프레임의 컬럼명
#  따옴표가 없는 table_size은 변수인가? 컬럼명인가?  --> 시리즈를 담은 변수명

table_size = tips['size']
table_size

# %%
# 4.3.3 시리즈 size의 앞 5개를 출력해보자.
table_size.head()

# %% [markdown]
# ### 4.4 연습문제
# - tips 데이터프레임에서 다음과 같이 추출해보자

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 4.4.1 봉사료 tips 데이터프레임에서 'smoker' 컬럼을 추출해보자.

...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 4.4.2 봉사료 tips 데이터프레임에서 'total_bill'과 'tip',  두 컬럼을 amount_df에 저장하고
#       amount_df를 출력해보자.

...

# %% [markdown]
# # 과제 제출 안내
#
# 지금까지 작성한 파일은 여러분의 구글 계정 G드라이브  > 내 문서 > Colab Notebooks 에 저장 되어 있습니다.  연습문제까지 모두 풀이 한 다음, 해당 파일을 다운로드 받아 강의실 내 '리포트' 로 제출하시기 바랍니다.
